# %% [markdown]
# ## 📊 Análise Exploratória do Dataset "Disney Plus Movies and TV Shows"
#
# Nesta análise exploratória, iremos examinar o dataset do Disney Plus Movies and TV Shows, que contém informações sobre os filmes e programas de TV disponíveis na plataforma Disney Plus. O dataset fornece informações sobre os registros que nos permitirão extrair insights, são elas:
#
# - `imdb_id`: Identificador único do filme ou série no IMDb.
# - `title`: Título do filme ou série.
# - `plot`: Sinopse ou resumo do enredo.
# - `type`: Indica se é um filme ou uma série.
# - `rated`: Classificação etária atribuída.
# - `year`: Ano de lançamento.
# - `released_at`: Data de lançamento.
# - `added_at`: Data em que foi adicionado ao Disney Plus.
# - `runtime`: Duração em minutos.
# - `genre`: Gêneros ou categorias aos quais pertence.
# - `director`: Diretor responsável pelo filme ou série.
# - `writer`: Escritor ou roteirista do filme ou série.
# - `actors`: Atores principais envolvidos no filme ou série.
# - `language`: Idioma original do filme ou série.
# - `country`: País de origem do filme ou série.
# - `awards`: Prêmios ou reconhecimentos recebidos.
# - `metascore`: Pontuação média do filme ou série no Metacritic.
# - `imdb_rating`: Avaliação do filme ou série no IMDb.
# - `imdb_votes`: Quantidade de votos no IMDb.

# %% [markdown]
# ### 📚 Instalação de Bibliotecas e Importação da Base de Dados

# %% [markdown]
# Nesta etapa, vamos garantir que todas as bibliotecas necessárias estejam instaladas e importar a base de dados do Disney Plus Movies and TV Shows. Para isso, vamos utilizar as bibliotecas pandas e pandasql, que nos permitirão manipular e analisar os dados do dataset.

# %%
# Instalando e importando as bibliotecas necessárias

# !pip install pandas
# !pip install pandasql
# !pip install sqlalchemy==1.4.46

import pandas as pd
import pandasql as ps
import os
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pandasql in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.5.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.4.46)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2022.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->pandasql) (2.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Requirement already satisfied: sqlalchemy==1.4.46 in /usr/local/lib/python3.10/dist-packages (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy==1.4.46) (2.0.2)

# %%
# Baixando o dataset do GitHub

! git clone https://github.com/renadeveloper/course_betech_database
# Out:
# fatal: destination path 'course_betech_database' already exists and is not an empty directory.

# %%
# Carregando o dataset

dados_disney = pd.read_csv('course_betech_database/disney_plus_shows.csv')
ps.sqldf("SELECT * FROM dados_disney LIMIT 10")
# Out:
#       imdb_id                                       title  \
# 0   tt0147800                  10 Things I Hate About You
# 1   tt7019028                        101 Dalmatian Street
# 2   tt0115433                              101 Dalmatians
# 3   tt0324941  101 Dalmatians 2: Patch's London Adventure
# 4   tt0211181                              102 Dalmatians
# 5   tt1846442                       12 Dates of Christmas
# 6   tt0046672                20,000 Leagues Under the Sea
# 7   tt0120623                                A Bug's Life
# 8  tt12076020        A Celebration of the Music from Coco
# 9   tt0113198                               A Goofy Movie
#
#                                                 plot    type  rated   year  \
# 0  A pretty, popular teenager can't go out on a d...   movie  PG-13   1999
# 1  This series follows the lives of Delilah and D...  series   None  2018–
# 2  An evil high-fashion designer plots to steal D...   movie      G   1996
# 3  Being one of 101 takes its toll on Patch, who ...   movie      G   2002
# 4  Cruella DeVil gets out of prison and goes afte...   movie      G   2000
# 5  A story that follows Kate, a young woman who a...   movie     PG   2011
# 6  A ship sent to investigate a wave of mysteriou...   movie      G   1954
# 7  A misfit ant, looking for "warriors" to save h...   movie      G   1998
# 8                                               None   movie   None   2020
# 9  When Max makes a preposterous promise to a gir...   movie      G   1995
#
#    released_at           added_at  runtime  \
# 0  31 Mar 1999  November 12, 2019   97 min
# 1  25 Mar 2019  February 28, 2020     None
# 2  27 Nov 1996  November 12, 2019  103 min
# 3  21 Jan 2003  November 12, 2019   74 min
# 4  22 Nov 2000  November 12, 2019  100 min
# 5  11 Dec 2011  November 12, 2019   90 min
# 6  20 Jul 1955  November 12, 2019  127 min
# 7  25 Nov 1998  November 12, 2019   95 min
# 8  10 Apr 2020     April 10, 2020     None
# 9  07 Apr 1995  November 12, 2019   78 min
#
#                                                genre  \
# 0                             Comedy, Drama, Romance
# 1                          Animation, Comedy, Family
# 2                   Adventure, Comedy, Crime, Family
# 3      Animation, Adventure, Comedy, Family, Musical
# 4                          Adventure, Comedy, Family
# 5                           Comedy, Fantasy, Romance
# 6          Adventure, Drama, Family, Fantasy, Sci-Fi
# 7               Animation, Adventure, Comedy, Family
# 8                                              Music
# 9  Animation, Adventure, Comedy, Family, Musical,...
#
#                                      director  \
# 0                                  Gil Junger
# 1                                        None
# 2                               Stephen Herek
# 3                   Jim Kammerud, Brian Smith
# 4                                  Kevin Lima
# 5                                James Hayman
# 6                           Richard Fleischer
# 7  John Lasseter, Andrew Stanton(co-director)
# 8                               Ron de Moraes
# 9                                  Kevin Lima
#
#                                               writer  \
# 0                      Karen McCullah, Kirsten Smith
# 1                                               None
# 2      Dodie Smith (novel), John Hughes (screenplay)
# 3  Jim Kammerud (story), Dan Root (story), Garret...
# 4  Dodie Smith (novel), Kristen Buckley (story), ...
# 5  Aaron Mendelsohn (teleplay), Janet Brownell (t...
# 6                           Earl Felton (screenplay)
# 7  John Lasseter (original story by), Andrew Stan...
# 8                                               None
# 9  Jymn Magon (story), Jymn Magon (screenplay), C...
#
#                                               actors          language  \
# 0  Heath Ledger, Julia Stiles, Joseph Gordon-Levi...   English, French
# 1  Josh Brener, Michaela Dietz, Bert Davis, Abiga...           English
# 2  Glenn Close, Jeff Daniels, Joely Richardson, J...  English, Spanish
# 3  Barry Bostwick, Jason Alexander, Martin Short,...           English
# 4  Glenn Close, Gérard Depardieu, Ioan Gruffudd, ...           English
# 5  Laura Miyata, Vijay Mehta, Amy Smart, Audrey D...           English
# 6  Kirk Douglas, James Mason, Paul Lukas, Peter L...           English
# 7  Dave Foley, Kevin Spacey, Julia Louis-Dreyfus,...           English
# 8                       Benjamin Bratt, Eva Longoria           English
# 9  Bill Farmer, Jason Marsden, Jim Cummings, Kell...           English
#
#                           country  \
# 0                             USA
# 1                 UK, USA, Canada
# 2                         USA, UK
# 3                             USA
# 4                         USA, UK
# 5                             USA
# 6                             USA
# 7                             USA
# 8                             USA
# 9  USA, Australia, France, Canada
#
#                                               awards  metascore  imdb_rating  \
# 0                           2 wins & 13 nominations.       70.0          7.3
# 1                                               None        NaN          6.2
# 2  Nominated for 1 Golden Globe. Another 3 wins &...       49.0          5.7
# 3                           5 wins & 10 nominations.        NaN          5.8
# 4  Nominated for 1 Oscar. Another 1 win & 7 nomin...       35.0          4.9
# 5                                      1 nomination.        NaN          6.3
# 6      Won 2 Oscars. Another 3 wins & 3 nominations.       83.0          7.2
# 7  Nominated for 1 Oscar. Another 14 wins & 20 no...       77.0          7.2
# 8                                               None        NaN          7.6
# 9                                     5 nominations.        NaN          6.8
#
#   imdb_votes
# 0    283,945
# 1        124
# 2     97,785
# 3      7,434
# 4     33,444
# 5      4,933
# 6     27,761
# 7    257,065
# 8         35
# 9     43,655

# %% [markdown]
# ### 📈 Análise Descritiva

# %% [markdown]
# Nesta seção, realizaremos uma análise descritiva dos dados do dataset do Disney Plus Movies and TV Shows e explorar as informações contidas nas colunas.

# %% [markdown]
# #### Qual a tipagem dos dados?

# %%
dados_disney.dtypes
# Out:
# imdb_id         object
# title           object
# plot            object
# type            object
# rated           object
# year            object
# released_at     object
# added_at        object
# runtime         object
# genre           object
# director        object
# writer          object
# actors          object
# language        object
# country         object
# awards          object
# metascore      float64
# imdb_rating    float64
# imdb_votes      object
# dtype: object

# %% [markdown]
# #### Quantos nulos temos em cada coluna?

# %%
dados_disney.isnull().sum()
# Out:
# imdb_id         98
# title           98
# plot           126
# type            98
# rated          250
# year            98
# released_at    118
# added_at         0
# runtime        154
# genre          107
# director       303
# writer         249
# actors         122
# language       127
# country        123
# awards         436
# metascore      700
# imdb_rating    113
# imdb_votes     113
# dtype: int64

# %% [markdown]
# #### Quantos valores únicos temos nas colunas categóricas?

# %%
# Para saber de outras colunas categóricas basta substituir type pelo nome da outra coluna

dados_disney['type'].value_counts()
# Out:
# movie      680
# series     191
# episode     23
# Name: type, dtype: int64

# %% [markdown]
# ### 🤔 Querys

# %% [markdown]
# #### Quantos filmes tem na base de dados?

# %%
ps.sqldf("SELECT count(*) AS qtd_filmes FROM dados_disney WHERE type = 'movie'")
# Out:
#    qtd_filmes
# 0         680

# %% [markdown]
# #### Quantos filmes a base de dados possui, que foram produzidos antes dos anos 2000?

# %%
ps.sqldf("SELECT count(*) AS total_filmes_antes_de_2000 FROM dados_disney WHERE type = 'movie' AND year < 2000 ")
# Out:
#    total_filmes_antes_de_2000
# 0                         283

# %% [markdown]
# #### Os 10 programas com maior quantidade de votos no IMDB.

# %%
ps.sqldf("SELECT title AS 'Titulo', imdb_votes AS 'Votos no IMDB' , type AS 'Estilo', imdb_rating AS 'Notas IMDB', year AS 'Ano de criação' FROM dados_disney ORDER BY imdb_votes DESC LIMIT 10")
# Out:
#                                               Titulo Votos no IMDB  Estilo  \
# 0                             The Incredible Dr. Pol           999  series
# 1                                    Elena of Avalor           998  series
# 2                                      Boat Builders           993   movie
# 3  Pirates of the Caribbean: The Curse of the Bla...       992,127   movie
# 4                                     Elmer Elephant           991   movie
# 5                                          Lamp Life           980   movie
# 6                          Atlantis: The Lost Empire        98,258   movie
# 7                                     101 Dalmatians        97,785   movie
# 8                                  The Good Dinosaur        97,413   movie
# 9                                             Willow        97,309   movie
#
#    Notas IMDB Ano de criação
# 0         8.6          2011–
# 1         6.4          2016–
# 2         7.3           1938
# 3         8.0           2003
# 4         7.0           1936
# 5         6.7           2020
# 6         6.9           2001
# 7         5.7           1996
# 8         6.7           2015
# 9         7.3           1988

# %% [markdown]
# #### Os 10 programas com a melhor pontuação IMDB, seus anos de lançamento e gênero/categoria.

# %%
ps.sqldf("SELECT title AS 'Título', imdb_rating AS 'Notas IMDB', type AS 'Estilo', year AS 'Ano de lançamento', genre AS 'Gênero' FROM dados_disney ORDER BY imdb_rating DESC LIMIT 10")
# Out:
#                                            Título  Notas IMDB  Estilo  \
# 0                                           Bluey         9.7  series
# 1                          The Imagineering Story         9.1  series
# 2                                   Gravity Falls         8.9  series
# 3                            Dr. T, Lone Star Vet         8.9  series
# 4                                  Muppet Moments         8.8  series
# 5                                One Strange Rock         8.8  series
# 6                     Lost Cities with Albert Lin         8.7  series
# 7  Star Wars: Episode V - The Empire Strikes Back         8.7   movie
# 8                                 The Mandalorian         8.7  series
# 9                                    The Simpsons         8.7  series
#
#   Ano de lançamento                                             Gênero
# 0             2018–                                          Animation
# 1             2019–                                        Documentary
# 2         2012–2016  Animation, Action, Adventure, Comedy, Family, ...
# 3             2019–                                         Reality-TV
# 4             2015–                                      Short, Family
# 5             2018–                                        Documentary
# 6             2019–                               Documentary, History
# 7              1980                 Action, Adventure, Fantasy, Sci-Fi
# 8             2019–                          Action, Adventure, Sci-Fi
# 9             1989–                                  Animation, Comedy

# %% [markdown]
# #### 10 principais categorias de programas adicionados ao Disney Plus em 2020.

# %%
ps.sqldf("SELECT genre AS 'Gênero' FROM dados_disney WHERE added_at LIKE '%2020%' LIMIT 10")
# Out:
#                                          Gênero
# 0                     Animation, Comedy, Family
# 1                                         Music
# 2                             Adventure, Family
# 3            Adventure, Family, Fantasy, Sci-Fi
# 4  Adventure, Family, Fantasy, Musical, Romance
# 5              Family, Comedy, Animation, Short
# 6                    Comedy, Family, Reality-TV
# 7                                   Documentary
# 8    Action, Adventure, Comedy, Family, Western
# 9                         Comedy, Family, Music

# %% [markdown]
# ####10 filmes lançados antes de 2000 do gênero Animação e com nota no IMDB > 8 adicionados no Disney Plus

# %%
ps.sqldf("SELECT title AS 'Título', imdb_rating AS 'Nota IMDB', released_at AS 'Data de lançamento', added_at AS 'Data de lançamento no Disney Plus' FROM dados_disney WHERE genre LIKE '%Documentary%' AND imdb_rating > 8 LIMIT 10" )
# Out:
#                                               Título  Nota IMDB  \
# 0                                   Before the Flood        8.3
# 1                                        Brain Games        8.3
# 2  Empire of Dreams: The Story of the 'Star Wars'...        8.3
# 3                                    Expedition Mars        8.1
# 4                                          Free Solo        8.2
# 5                                   Great Migrations        8.1
# 6                                     Hostile Planet        8.2
# 7                       In the Footsteps of Elephant        8.1
# 8                          Kingdom of the White Wolf        8.2
# 9                        Lost Cities with Albert Lin        8.7
#
#   Data de lançamento Data de lançamento no Disney Plus
# 0        30 Oct 2016                 November 12, 2019
# 1        09 Oct 2011                 November 12, 2019
# 2        20 Sep 2004                 November 12, 2019
# 3        16 Nov 2016                 November 12, 2019
# 4        13 Dec 2018                 November 12, 2019
# 5        07 Nov 2010                 November 12, 2019
# 6        01 Apr 2019                 November 12, 2019
# 7        03 Apr 2020                     April 3, 2020
# 8        25 Aug 2019                 November 12, 2019
# 9        01 Oct 2019                 February 21, 2020

# %% [markdown]
# ####10 filmes lançados antes de 2000 do gênero Familia e com nota no IMDB > 8 adicionados no Disney Plus

# %%
ps.sqldf("SELECT title AS 'Título', imdb_rating AS 'Nota IMDB', released_at AS 'Data de lançamento', added_at AS 'Data de lançamento no Disney Plus' FROM dados_disney WHERE genre LIKE '%Family%' AND year <2000 AND imdb_rating > 8 LIMIT 10" )
# Out:
#                              Título  Nota IMDB Data de lançamento  \
# 0                   Boy Meets World        8.1        24 Sep 1993
# 1                         DuckTales        8.1        18 Sep 1987
# 2                         Gargoyles        8.1        24 Oct 1994
# 3   Spider-Man: The Animated Series        8.3        19 Nov 1994
# 4        X-Men: The Animated Series        8.4        31 Oct 1992
# 5          Mickey's Christmas Carol        8.1        16 Dec 1983
# 6        Prowlers of the Everglades        8.1        23 Jul 1953
# 7                          So Weird        8.5        18 Jan 1999
# 8  The Adventures of Spin and Marty        8.2        04 Nov 1955
# 9                     The Lion King        8.5        24 Jun 1994
#
#   Data de lançamento no Disney Plus
# 0                 November 12, 2019
# 1                 November 12, 2019
# 2                 November 12, 2019
# 3                 November 12, 2019
# 4                 November 12, 2019
# 5                 November 12, 2019
# 6                       May 1, 2020
# 7                 November 12, 2019
# 8                 November 12, 2019
# 9                 November 12, 2019

# %% [markdown]
# ####10 programas adicionados no Disney Plus com maior nota no IMDB lançados após 2000

# %%
ps.sqldf("SELECT title AS 'Título', genre AS 'Gênero', imdb_rating AS 'Nota IMDB', released_at AS 'Data de lançamento', added_at AS 'Data de lançamento no Disney Plus' FROM dados_disney WHERE year >2000 ORDER BY imdb_rating DESC LIMIT 10" )
# Out:
#                                     Título  \
# 0                                    Bluey
# 1                   The Imagineering Story
# 2                            Gravity Falls
# 3                     Dr. T, Lone Star Vet
# 4                           Muppet Moments
# 5                         One Strange Rock
# 6              Lost Cities with Albert Lin
# 7                          The Mandalorian
# 8                   The Incredible Dr. Pol
# 9  Disney's Newsies: The Broadway Musical!
#
#                                               Gênero  Nota IMDB  \
# 0                                          Animation        9.7
# 1                                        Documentary        9.1
# 2  Animation, Action, Adventure, Comedy, Family, ...        8.9
# 3                                         Reality-TV        8.9
# 4                                      Short, Family        8.8
# 5                                        Documentary        8.8
# 6                               Documentary, History        8.7
# 7                          Action, Adventure, Sci-Fi        8.7
# 8                            Documentary, Reality-TV        8.6
# 9                                            Musical        8.5
#
#   Data de lançamento Data de lançamento no Disney Plus
# 0        09 Sep 2019                  January 22, 2020
# 1        12 Nov 2019                 November 12, 2019
# 2        15 Jun 2012                 November 12, 2019
# 3        13 Oct 2019                   January 1, 2020
# 4        03 Apr 2015                 November 12, 2019
# 5        26 Mar 2018                   January 1, 2020
# 6        01 Oct 2019                 February 21, 2020
# 7        12 Nov 2019                 November 12, 2019
# 8               None                 November 12, 2019
# 9        16 Feb 2017                 November 12, 2019

# %% [markdown]
# #### Quais programas não estadunidenses possui a base?

# %%
ps.sqldf("SELECT title AS 'Título', type AS 'Tipo de programa', country AS 'País' FROM dados_disney WHERE country NOT LIKE '%USA%'" )
# Out:
#                                                Título Tipo de programa  \
# 0                                     Atlantis Rising            movie
# 1                                               Bluey           series
# 2                                           Deep Blue            movie
# 3                             Diana: In Her Own Words            movie
# 4                                        Bad Hair Day            movie
# 5                                    Drain the Oceans           series
# 6                        Drain the Sunken Pirate City            movie
# 7    The New Yoda Chronicles: Clash of the Skywalkers            movie
# 8          The New Yoda Chronicles: Raid on Coruscant            movie
# 9   The New Yoda Chronicles: Escape from the Jedi ...            movie
# 10                                           Millions            movie
# 11                                           PJ Masks           series
# 12                          Secrets of the King Cobra            movie
# 13                                           So Weird           series
# 14                                           Soy Luna           series
# 15                                Stonehenge: Decoded            movie
# 16                                          The Lodge           series
# 17               The Lost Tomb of Alexander the Great            movie
# 18                          The Prince and the Pauper            movie
# 19         The Story of Robin Hood and His Merrie Men            movie
# 20                                 Trail of the Panda            movie
# 21                                    Treasure Island            movie
# 22                            Tutankhamen's Treasures           series
# 23                               Viking Warrior Women            movie
# 24                                           Violetta           series
#
#                  País
# 0              Canada
# 1       Australia, UK
# 2         UK, Germany
# 3                  UK
# 4              Canada
# 5       UK, Australia
# 6                  UK
# 7      Denmark, China
# 8      Denmark, China
# 9      Denmark, China
# 10                 UK
# 11         France, UK
# 12              India
# 13             Canada
# 14  Argentina, Mexico
# 15                 UK
# 16                 UK
# 17                 UK
# 18                 UK
# 19                 UK
# 20              China
# 21                 UK
# 22                 UK
# 23                 UK
# 24          Argentina

# %% [markdown]
# #### Quantos programas ganharam algum tipo de premiação?

# %%
ps.sqldf("SELECT count(*) AS total_filmes_premiados FROM dados_disney WHERE awards LIKE '%win%' ")
# Out:
#    total_filmes_premiados
# 0                     376

# %% [markdown]
# #### Dos programas não estadunidenses da consulta anterior, quais deles possui premiação?

# %%
ps.sqldf("SELECT title AS 'Título', type AS 'Tipo de programa', country AS 'País', awards AS 'Premiação' FROM dados_disney WHERE country NOT LIKE '%USA%' AND awards LIKE '%win%'"  )
# Out:
#                     Título Tipo de programa           País  \
# 0                    Bluey           series  Australia, UK
# 1  Diana: In Her Own Words            movie             UK
# 2         Drain the Oceans           series  UK, Australia
# 3                 Millions            movie             UK
# 4                 PJ Masks           series     France, UK
# 5                 Violetta           series      Argentina
#
#                  Premiação
# 0                  4 wins.
# 1                  2 wins.
# 2                   1 win.
# 3  2 wins & 7 nominations.
# 4  2 wins & 6 nominations.
# 5   1 win & 2 nominations.

# %% [markdown]
# ### 💡 Conclusões

# %% [markdown]
# Algumas análises que pudemos fazer relacionada ao dataset de programação do Disney Plus são:
# - O tipo de programa que tem mais variedades na plataforma são os filmes, a base conta com 76% de filmes, 21% de séries e 3% de episódios isolados;
# - A maior parte dos filmes adicionados a plataforma foram produzidos após os anos 2000, cerca de 58%;
# - Nenhum dos 10 programas mais votados estão entre os 10 programas com melhor pontuação IMDB;
# - Os gêneros com as maiores quantidades de programas na base de dados são comédia e família, porém o gênero presente mais vezes entre os 10 programas com as melhores avaliações foi documentário;
# - A base de dados possui apenas 25 programas que não foram produzidos nos Estados Unidos, ou seja, apenas 2,8% do total de programas e, entre eles, apenas 6 possuem algum tipo de premiação, 1,6% da relação de programas premiados da base;
